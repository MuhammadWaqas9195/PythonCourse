# %%
#import the necessary libraries for analysis
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn

# %%
#Importing dataset
url = 'https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv'
df = pd.read_csv(url)

# %%
#Structure of the data
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# 2                Living Environment  2016             9         74
# 3               Common Core Algebra  2016             3          s
# 4               Common Core Algebra  2017             2          s
# ...                             ...   ...           ...        ...
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 0                            s                        s
# 1                            1                      6.3
# 2                            1                     11.1
# 3                            s                        s
# 4                            s                        s
# ...                        ...                      ...
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# 212329                       s                        s
# 212330                       s                        s
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# 0                               s                           s
# 1                              15                        93.8
# 2                               8                        88.9
# 3                               s                           s
# 4                               s                           s
# ...                           ...                         ...
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above  \
# 0                               s                           s
# 1                               7                        43.8
# 2                               2                        22.2
# 3                               s                           s
# 4                               s                           s
# ...                           ...                         ...
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
#        Number Scoring CR Percent Scoring CR
# 0                     na                 na
# 1                     na                 na
# 2                     na                 na
# 3                     na                 na
# 4                     na                 na
# ...                  ...                ...
# 212326                na                 na
# 212327                na                 na
# 212328                na                 na
# 212329                na                 na
# 212330                na                 na
#
# [212331 rows x 15 columns]

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df.isnull().sum() #for cleaning
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True) # it will add NA and not affecting data

# %%
df.dtypes
# Out:
# School DBN                     object
# School Name                    object
# School Level                   object
# Regents Exam                   object
# Year                            int64
# Total Tested                    int64
# Mean Score                     object
# Number Scoring Below 65        object
# Percent Scoring Below 65       object
# Number Scoring 65 or Above     object
# Percent Scoring 65 or Above    object
# Number Scoring 80 or Above     object
# Percent Scoring 80 or Above    object
# Number Scoring CR              object
# Percent Scoring CR             object
# dtype: object

# %%
df.head() # Display the first few rows to confirm the data is loaded correctly
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# 1                      6.3                         15
# 2                     11.1                          8
# 3                        s                          s
# 4                        s                          s
#
#   Percent Scoring 65 or Above Number Scoring 80 or Above  \
# 0                           s                          s
# 1                        93.8                          7
# 2                        88.9                          2
# 3                           s                          s
# 4                           s                          s
#
#   Percent Scoring 80 or Above Number Scoring CR Percent Scoring CR
# 0                           s                na                 na
# 1                        43.8                na                 na
# 2                        22.2                na                 na
# 3                           s                na                 na
# 4                           s                na                 na

# %%
df['School Name'].unique() #This code will output an array of unique school names, which can be used for further processing or analysis.
# Out:
# array(['P.S. 034 Franklin D. Roosevelt', 'P.S. 140 Nathan Straus',
#        'P.S. 184m Shuang Wen', ..., 'Family Life Academy Charter School',
#        'Harriet Tubman Charter School', 'Icahn Charter School'],
#       dtype=object)

# %%
df.info() # Display summary information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 212321 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212321 non-null  object
#  1   School Name                  212321 non-null  object
#  2   School Level                 212321 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212321 non-null  int64
#  5   Total Tested                 212321 non-null  int64
#  6   Mean Score                   212321 non-null  object
#  7   Number Scoring Below 65      212321 non-null  object
#  8   Percent Scoring Below 65     212321 non-null  object
#  9   Number Scoring 65 or Above   212321 non-null  object
#  10  Percent Scoring 65 or Above  212321 non-null  object
#  11  Number Scoring 80 or Above   212321 non-null  object
#  12  Percent Scoring 80 or Above  212321 non-null  object
#  13  Number Scoring CR            212321 non-null  object
#  14  Percent Scoring CR           212321 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 25.9+ MB

# %%
df.groupby(['School Name']).count() #This code is used to group the data by the 'School Name' column and count the number of rows in each group,
#which helps to summarize the data by identifying the number of records for each school.
# Out:
#                                                     School DBN  School Level  \
# School Name
# 47 The American Sign Language and English Secondar         356           356
# A. Philip Randolph Campus High School                      459           459
# ACORN Community High School                                364           364
# Abraham Lincoln High School                                480           480
# Abraham Lincoln Yabc                                       248           248
# ...                                                        ...           ...
# Young Women's Leadership School                            378           378
# Young Women's Leadership School of Brooklyn                337           337
# Young Women's Leadership School of the Bronx               142           142
# Young Women's Leadership School, Astoria                   338           338
# Young Women's Leadership School, Queens                    391           391
#
#                                                     Regents Exam  Year  \
# School Name
# 47 The American Sign Language and English Secondar           356   356
# A. Philip Randolph Campus High School                        459   459
# ACORN Community High School                                  364   364
# Abraham Lincoln High School                                  480   480
# Abraham Lincoln Yabc                                         248   248
# ...                                                          ...   ...
# Young Women's Leadership School                              378   378
# Young Women's Leadership School of Brooklyn                  337   337
# Young Women's Leadership School of the Bronx                 142   142
# Young Women's Leadership School, Astoria                     338   338
# Young Women's Leadership School, Queens                      391   391
#
#                                                     Total Tested  Mean Score  \
# School Name
# 47 The American Sign Language and English Secondar           356         356
# A. Philip Randolph Campus High School                        459         459
# ACORN Community High School                                  364         364
# Abraham Lincoln High School                                  480         480
# Abraham Lincoln Yabc                                         248         248
# ...                                                          ...         ...
# Young Women's Leadership School                              378         378
# Young Women's Leadership School of Brooklyn                  337         337
# Young Women's Leadership School of the Bronx                 142         142
# Young Women's Leadership School, Astoria                     338         338
# Young Women's Leadership School, Queens                      391         391
#
#                                                     Number Scoring Below 65  \
# School Name
# 47 The American Sign Language and English Secondar                      356
# A. Philip Randolph Campus High School                                   459
# ACORN Community High School                                             364
# Abraham Lincoln High School                                             480
# Abraham Lincoln Yabc                                                    248
# ...                                                                     ...
# Young Women's Leadership School                                         378
# Young Women's Leadership School of Brooklyn                             337
# Young Women's Leadership School of the Bronx                            142
# Young Women's Leadership School, Astoria                                338
# Young Women's Leadership School, Queens                                 391
#
#                                                     Percent Scoring Below 65  \
# School Name
# 47 The American Sign Language and English Secondar                       356
# A. Philip Randolph Campus High School                                    459
# ACORN Community High School                                              364
# Abraham Lincoln High School                                              480
# Abraham Lincoln Yabc                                                     248
# ...                                                                      ...
# Young Women's Leadership School                                          378
# Young Women's Leadership School of Brooklyn                              337
# Young Women's Leadership School of the Bronx                             142
# Young Women's Leadership School, Astoria                                 338
# Young Women's Leadership School, Queens                                  391
#
#                                                     Number Scoring 65 or Above  \
# School Name
# 47 The American Sign Language and English Secondar                         356
# A. Philip Randolph Campus High School                                      459
# ACORN Community High School                                                364
# Abraham Lincoln High School                                                480
# Abraham Lincoln Yabc                                                       248
# ...                                                                        ...
# Young Women's Leadership School                                            378
# Young Women's Leadership School of Brooklyn                                337
# Young Women's Leadership School of the Bronx                               142
# Young Women's Leadership School, Astoria                                   338
# Young Women's Leadership School, Queens                                    391
#
#                                                     Percent Scoring 65 or Above  \
# School Name
# 47 The American Sign Language and English Secondar                          356
# A. Philip Randolph Campus High School                                       459
# ACORN Community High School                                                 364
# Abraham Lincoln High School                                                 480
# Abraham Lincoln Yabc                                                        248
# ...                                                                         ...
# Young Women's Leadership School                                             378
# Young Women's Leadership School of Brooklyn                                 337
# Young Women's Leadership School of the Bronx                                142
# Young Women's Leadership School, Astoria                                    338
# Young Women's Leadership School, Queens                                     391
#
#                                                     Number Scoring 80 or Above  \
# School Name
# 47 The American Sign Language and English Secondar                         356
# A. Philip Randolph Campus High School                                      459
# ACORN Community High School                                                364
# Abraham Lincoln High School                                                480
# Abraham Lincoln Yabc                                                       248
# ...                                                                        ...
# Young Women's Leadership School                                            378
# Young Women's Leadership School of Brooklyn                                337
# Young Women's Leadership School of the Bronx                               142
# Young Women's Leadership School, Astoria                                   338
# Young Women's Leadership School, Queens                                    391
#
#                                                     Percent Scoring 80 or Above  \
# School Name
# 47 The American Sign Language and English Secondar                          356
# A. Philip Randolph Campus High School                                       459
# ACORN Community High School                                                 364
# Abraham Lincoln High School                                                 480
# Abraham Lincoln Yabc                                                        248
# ...                                                                         ...
# Young Women's Leadership School                                             378
# Young Women's Leadership School of Brooklyn                                 337
# Young Women's Leadership School of the Bronx                                142
# Young Women's Leadership School, Astoria                                    338
# Young Women's Leadership School, Queens                                     391
#
#                                                     Number Scoring CR  \
# School Name
# 47 The American Sign Language and English Secondar                356
# A. Philip Randolph Campus High School                             459
# ACORN Community High School                                       364
# Abraham Lincoln High School                                       480
# Abraham Lincoln Yabc                                              248
# ...                                                               ...
# Young Women's Leadership School                                   378
# Young Women's Leadership School of Brooklyn                       337
# Young Women's Leadership School of the Bronx                      142
# Young Women's Leadership School, Astoria                          338
# Young Women's Leadership School, Queens                           391
#
#                                                     Percent Scoring CR
# School Name
# 47 The American Sign Language and English Secondar                 356
# A. Philip Randolph Campus High School                              459
# ACORN Community High School                                        364
# Abraham Lincoln High School                                        480
# Abraham Lincoln Yabc                                               248
# ...                                                                ...
# Young Women's Leadership School                                    378
# Young Women's Leadership School of Brooklyn                        337
# Young Women's Leadership School of the Bronx                       142
# Young Women's Leadership School, Astoria                           338
# Young Women's Leadership School, Queens                            391
#
# [1012 rows x 14 columns]

# %%
df['School Name'].value_counts() # show how many times in the table
# Out:
# School Name
# New Visions Charter High School for Advanced Math     1337
# New Visions Charter High School for the Humanities    1031
# Francis Lewis High School                              490
# James Madison High School                              490
# Long Island City High School                           489
#                                                       ...
# Middle School for Academic and Social Excellence         5
# P.S. 202 Ernest S. Jenkyns                               5
# J.H.S. 166 George Gershwin                               5
# Success Academy Charter School - Harlem 3                5
# Explore Excel Charter School                             5
# Name: count, Length: 1012, dtype: int64

# %%
df.loc[:,'School Name'] #its only showing all rows and specific column
# Out:
# 0         P.S. 034 Franklin D. Roosevelt
# 1         P.S. 034 Franklin D. Roosevelt
# 2         P.S. 034 Franklin D. Roosevelt
# 3                 P.S. 140 Nathan Straus
# 4                 P.S. 140 Nathan Straus
#                        ...
# 212326              Icahn Charter School
# 212327              Icahn Charter School
# 212328              Icahn Charter School
# 212329              Icahn Charter School
# 212330              Icahn Charter School
# Name: School Name, Length: 212321, dtype: object

# %%
df1=df[['School Name','Regents Exam','Year','Total Tested','Percent Scoring Below 65','Percent Scoring 65 or Above','Percent Scoring 80 or Above']]#making ubset

# %%
df1
# Out:
#                            School Name                 Regents Exam  Year  \
# 0       P.S. 034 Franklin D. Roosevelt          Common Core Algebra  2017
# 1       P.S. 034 Franklin D. Roosevelt           Living Environment  2015
# 2       P.S. 034 Franklin D. Roosevelt           Living Environment  2016
# 3               P.S. 140 Nathan Straus          Common Core Algebra  2016
# 4               P.S. 140 Nathan Straus          Common Core Algebra  2017
# ...                                ...                          ...   ...
# 212326            Icahn Charter School           Living Environment  2016
# 212327            Icahn Charter School           Living Environment  2016
# 212328            Icahn Charter School           Living Environment  2017
# 212329            Icahn Charter School           Living Environment  2017
# 212330            Icahn Charter School  U.S. History and Government  2015
#
#         Total Tested Percent Scoring Below 65 Percent Scoring 65 or Above  \
# 0                  4                        s                           s
# 1                 16                      6.3                        93.8
# 2                  9                     11.1                        88.9
# 3                  3                        s                           s
# 4                  2                        s                           s
# ...              ...                      ...                         ...
# 212326             8                        s                           s
# 212327             5                        s                           s
# 212328             6                        s                           s
# 212329             4                        s                           s
# 212330             1                        s                           s
#
#        Percent Scoring 80 or Above
# 0                                s
# 1                             43.8
# 2                             22.2
# 3                                s
# 4                                s
# ...                            ...
# 212326                           s
# 212327                           s
# 212328                           s
# 212329                           s
# 212330                           s
#
# [212321 rows x 7 columns]

# %%
df1.shape
# Out:
# (212321, 7)

# %%
df1.describe()
# Out:
#                 Year   Total Tested
# count  212321.000000  212321.000000
# mean     2015.956114      49.364406
# std         0.799718      93.025538
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df1.drop_duplicates(inplace=True) #This method checks for duplicate rows in the DataFrame and removes them. By default, 
#it considers all columns to identify duplicates, but you can specify certain columns if you only want to consider duplicates based on those columns.
# Out:
# C:\Users\marya\AppData\Local\Temp\ipykernel_15160\3543175249.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop_duplicates(inplace=True) #This method checks for duplicate rows in the DataFrame and removes them. By default, it considers all columns to identify duplicates, but you can specify certain columns if you only want to consider duplicates based on those columns.

# %%
df1
# Out:
#                            School Name         Regents Exam  Year  \
# 0       P.S. 034 Franklin D. Roosevelt  Common Core Algebra  2017
# 1       P.S. 034 Franklin D. Roosevelt   Living Environment  2015
# 2       P.S. 034 Franklin D. Roosevelt   Living Environment  2016
# 3               P.S. 140 Nathan Straus  Common Core Algebra  2016
# 4               P.S. 140 Nathan Straus  Common Core Algebra  2017
# ...                                ...                  ...   ...
# 212325            Icahn Charter School   Living Environment  2015
# 212326            Icahn Charter School   Living Environment  2016
# 212327            Icahn Charter School   Living Environment  2016
# 212328            Icahn Charter School   Living Environment  2017
# 212329            Icahn Charter School   Living Environment  2017
#
#         Total Tested Percent Scoring Below 65 Percent Scoring 65 or Above  \
# 0                  4                        s                           s
# 1                 16                      6.3                        93.8
# 2                  9                     11.1                        88.9
# 3                  3                        s                           s
# 4                  2                        s                           s
# ...              ...                      ...                         ...
# 212325             6                        0                         100
# 212326             8                        s                           s
# 212327             5                        s                           s
# 212328             6                        s                           s
# 212329             4                        s                           s
#
#        Percent Scoring 80 or Above
# 0                                s
# 1                             43.8
# 2                             22.2
# 3                                s
# 4                                s
# ...                            ...
# 212325                        33.3
# 212326                           s
# 212327                           s
# 212328                           s
# 212329                           s
#
# [187707 rows x 7 columns]

# %%
df1.duplicated() #dentifying Duplicates: Quickly identifying which rows in your DataFrame are duplicates.
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 212325    False
# 212326    False
# 212327    False
# 212328    False
# 212329    False
# Length: 187707, dtype: bool

# %%
df1.groupby(['School Name'])['Total Tested'].count().sort_values(ascending=False)
#Summarizing Data: Quickly understanding which schools have the most or least number of entries in the dataset.
#Data Analysis: Identifying patterns or anomalies in the data, such as schools with unusually high or low counts.
#Reporting: Creating summaries or reports that highlight key statistics.
# Out:
# School Name
# New Visions Charter High School for Advanced Math     1128
# New Visions Charter High School for the Humanities     864
# Edward R. Murrow High School                           487
# James Madison High School                              486
# John Dewey High School                                 485
#                                                       ...
# Explore Excel Charter School                             1
# P.S./M.S. 11X498 - VAN NEST ACADEMY                      1
# J.H.S. 166 George Gershwin                               1
# P.S./M.S. 20 P.O.George J. Werdann, III                  1
# J.H.S. 302 Rafael Cordero                                1
# Name: Total Tested, Length: 1012, dtype: int64

# %%
filtering_1 = df[(df['School DBN'] == '20K490') | (df['School DBN'] == '20K658')]
#For analyisis, creating a dataset that only shows test scores for Fort Hamilton High School and Franklin Delano Rossevelt High School.

# %%
filtering_1
# Out:
#        School DBN                     School Name School Level  \
# 12201      20K490       Fort Hamilton High School  High school
# 12202      20K490       Fort Hamilton High School  High school
# 12203      20K490       Fort Hamilton High School  High school
# 12204      20K490       Fort Hamilton High School  High school
# 12205      20K490       Fort Hamilton High School  High school
# ...           ...                             ...          ...
# 185109     20K658  Franklin Delano Roosevelt YABC  High school
# 185110     20K658  Franklin Delano Roosevelt YABC  High school
# 185111     20K658  Franklin Delano Roosevelt YABC  High school
# 185112     20K658  Franklin Delano Roosevelt YABC  High school
# 185113     20K658  Franklin Delano Roosevelt YABC  High school
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 12201         Algebra2/Trigonometry  2015           709       67.2
# 12202         Algebra2/Trigonometry  2016           669       62.2
# 12203           Common Core Algebra  2015           707         66
# 12204           Common Core Algebra  2016          1248       69.4
# 12205           Common Core Algebra  2017          1313       71.7
# ...                             ...   ...           ...        ...
# 185109  U.S. History and Government  2016            32         58
# 185110  U.S. History and Government  2016             8       54.8
# 185111  U.S. History and Government  2017             4          s
# 185112  U.S. History and Government  2017             3          s
# 185113  U.S. History and Government  2017            21       56.9
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 12201                      303                     42.7
# 12202                      379                     56.7
# 12203                      233                       33
# 12204                      364                     29.2
# 12205                      297                     22.6
# ...                        ...                      ...
# 185109                      22                     68.8
# 185110                       6                       75
# 185111                       s                        s
# 185112                       s                        s
# 185113                      15                     71.4
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# 12201                         406                        57.3
# 12202                         290                        43.3
# 12203                         474                          67
# 12204                         884                        70.8
# 12205                        1016                        77.4
# ...                           ...                         ...
# 185109                         10                        31.3
# 185110                          2                          25
# 185111                          s                           s
# 185112                          s                           s
# 185113                          6                        28.6
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above  \
# 12201                         212                        29.9
# 12202                         159                        23.8
# 12203                          26                         3.7
# 12204                         232                        18.6
# 12205                         373                        28.4
# ...                           ...                         ...
# 185109                          1                         3.1
# 185110                          0                           0
# 185111                          s                           s
# 185112                          s                           s
# 185113                          0                           0
#
#        Number Scoring CR Percent Scoring CR
# 12201                212               29.9
# 12202                159               23.8
# 12203                287               40.6
# 12204                702               56.3
# 12205                872               66.4
# ...                  ...                ...
# 185109                na                 na
# 185110                na                 na
# 185111                na                 na
# 185112                na                 na
# 185113                na                 na
#
# [758 rows x 15 columns]

# %%
#Statistical Summary of the Dataset
filtering_1.describe().T
# Out:
#               count         mean         std     min     25%     50%      75%  \
# Year          758.0  2015.926121    0.781103  2015.0  2015.0  2016.0  2017.00
# Total Tested  758.0   197.315303  271.818169     1.0    10.0    48.5   305.75
#
#                  max
# Year          2017.0
# Total Tested  1416.0

# %%
filtering_1.describe(include='object').T
# Out:
#                             count unique                           top freq
# School DBN                    758      2                        20K490  475
# School Name                   758      2     Fort Hamilton High School  475
# School Level                  758      1                   High school  758
# Regents Exam                  758     14  Global History and Geography   75
# Mean Score                    758    303                             s  146
# Number Scoring Below 65       758    204                             s  146
# Percent Scoring Below 65      758    366                             s  146
# Number Scoring 65 or Above    758    302                             s  146
# Percent Scoring 65 or Above   758    364                             s  146
# Number Scoring 80 or Above    758    212                             s  146
# Percent Scoring 80 or Above   758    339                             s  146
# Number Scoring CR             758    151                            na  469
# Percent Scoring CR            758    215                            na  469

# %%
# Visualizing the data
import matplotlib.pyplot as plt
filtering_1.plot(kind = 'bar', x='School Name', y='Mean Score', title = 'Comparing Results', xlabel = 'School Name', ylabel = 'Comparing result', legend = False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 # Visualizing the data
#       2 import matplotlib.pyplot as plt
# ----> 3 filtering_1.plot(kind = 'bar', x='School Name', y='Mean Score', title = 'Comparing Results', xlabel = 'School Name', ylabel = 'Comparing result', legend = False)
#       4 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:451, in MPLPlot.generate(self)
#     449 def generate(self) -> None:
#     450     self._args_adjust()
# --> 451     self._compute_plot_data()
#     452     self._setup_subplots()
#     453     self._make_plot()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:636, in MPLPlot._compute_plot_data(self)
#     634 # no non-numeric frames or series allowed
#     635 if is_empty:
# --> 636     raise TypeError("no numeric data to plot")
#     638 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot
