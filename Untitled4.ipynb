# %%
# !pip istall pandas
# !pip install matplotlib
# Out:
# ERROR: unknown command "istall" - maybe you meant "install"
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/10000%20Sales%20Records.csv')

# %%
df.head(5)
# Out:
#                          Region                           Country  \
# 0            Sub-Saharan Africa                              Chad
# 1                        Europe                            Latvia
# 2  Middle East and North Africa                          Pakistan
# 3            Sub-Saharan Africa  Democratic Republic of the Congo
# 4                        Europe                    Czech Republic
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0  Office Supplies        Online              L   1/27/2011  292494523
# 1        Beverages        Online              C  12/28/2015  361825549
# 2       Vegetables       Offline              C   1/13/2011  141515767
# 3        Household        Online              C   9/11/2012  500364005
# 4        Beverages        Online              C  10/27/2015  127481591
#
#    Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# ...

# %%
df.head(2)
# Out:
#                Region Country        Item Type Sales Channel Order Priority  \
# 0  Sub-Saharan Africa    Chad  Office Supplies        Online              L
# 1              Europe  Latvia        Beverages        Online              C
#
#    Order Date   Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0   1/27/2011  292494523  2/12/2011        4484      651.21     524.96
# 1  12/28/2015  361825549  1/23/2016        1075       47.45      31.79
#
#    Total Revenue  Total Cost  Total Profit
# 0     2920025.64  2353920.64      566105.0
# 1       51008.75    34174.25       16834.5

# %%
df.tail(5)
# Out:
#                   Region                           Country   Item Type  \
# 9995                Asia                              Laos   Beverages
# 9996              Europe                     Liechtenstein   Cosmetics
# 9997  Sub-Saharan Africa  Democratic Republic of the Congo  Vegetables
# 9998  Sub-Saharan Africa                      South Africa        Meat
# 9999                Asia                          Mongolia      Snacks
#
#      Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 9995        Online              H   7/15/2014  199342048  7/31/2014
# 9996        Online              C  10/27/2012  763044106  11/1/2012
# 9997       Offline              M   2/14/2013  848579967  3/20/2013
# 9998        Online              L   2/19/2017  298185956  2/22/2017
# 9999       Offline              M   4/12/2016  824410903  4/16/2016
#
#       Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# ...

# %%
df.tail(3)
# Out:
#                   Region                           Country   Item Type  \
# 9997  Sub-Saharan Africa  Democratic Republic of the Congo  Vegetables
# 9998  Sub-Saharan Africa                      South Africa        Meat
# 9999                Asia                          Mongolia      Snacks
#
#      Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# 9997       Offline              M  2/14/2013  848579967  3/20/2013
# 9998        Online              L  2/19/2017  298185956  2/22/2017
# 9999       Offline              M  4/12/2016  824410903  4/16/2016
#
#       Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 9997        2524      154.06      90.93      388847.44   229507.32
# 9998        8706      421.89     364.69     3672974.34  3174991.14
# 9999         361      152.58      97.44       55081.38    35175.84
#
#       Total Profit
# 9997     159340.12
# 9998     497983.20
# 9999      19905.54

# %%
df.mean()
# Out:
# <ipython-input-16-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Order ID         5.498719e+08
# Units Sold       5.002856e+03
# Unit Price       2.681431e+02
# Unit Cost        1.888066e+02
# Total Revenue    1.333355e+06
# Total Cost       9.382658e+05
# Total Profit     3.950893e+05
# dtype: float64

# %%
df.min()
# Out:
# Region                   Asia
# Country           Afghanistan
# Item Type           Baby Food
# Sales Channel         Offline
# Order Priority              C
# Order Date           1/1/2010
# Order ID            100089156
# Ship Date            1/1/2011
# Units Sold                  2
# Unit Price               9.33
# Unit Cost                6.92
# Total Revenue          167.94
# Total Cost             124.56
# Total Profit            43.38
# dtype: object

# %%
df[df['Item Type']=='Baby Food']
# Out:
#                                  Region                         Country  \
# 7                                  Asia                           China
# 11                               Europe          Bosnia and Herzegovina
# 27                               Europe                         Albania
# 28                Australia and Oceania  Federated States of Micronesia
# 32    Central America and the Caribbean             Trinidad and Tobago
# ...                                 ...                             ...
# 9885  Central America and the Caribbean                         Jamaica
# 9898                 Sub-Saharan Africa                        Cameroon
# 9910              Australia and Oceania                Papua New Guinea
# 9920                 Sub-Saharan Africa                          Malawi
# 9993              Australia and Oceania                Marshall Islands
#
#       Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
df['Region'].min()
# Out:
# 'Asia'
